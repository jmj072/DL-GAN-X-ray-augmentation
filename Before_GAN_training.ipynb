# %% [markdown]
# **기존 Dataset을 이용해 CNN 학습**
# - 정상군 : 1266명
# - 코로나19 환자 : 460명

# %% [markdown]
# #라이브러리 및 패키지

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import time
import PIL
import tensorflow as tf

#모델 생성
from tensorflow.keras import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import array_to_img, img_to_array, load_img, image_dataset_from_directory
from keras.callbacks import ModelCheckpoint, EarlyStopping

#모델저장
import joblib

# %% [markdown]
# # 데이터셋 형성 및 이미지 전처리

# %%
#구글 드라이브 mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 이미지 관련 변수, 모델학습 변수

batch_size = 128
img_height = 128
img_width = 128
seed = 42
epoch = 500

# %%
# Dataset 형성

train_path="/content/drive/MyDrive/CodeStates/Section4/project/Before_GAN/train"
test_path="/content/drive/MyDrive/CodeStates/Section4/project/Before_GAN/test"

train_ds = image_dataset_from_directory(
  train_path,
  validation_split=0.2,
  subset="training",
  seed=seed,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = image_dataset_from_directory(
  train_path,
  validation_split=0.2,
  subset="validation",
  seed=seed,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_ds =  image_dataset_from_directory(
  test_path,
  seed=seed,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1726 files belonging to 2 classes.
# Using 1381 files for training.
# Found 1726 files belonging to 2 classes.
# Using 345 files for validation.
# Found 433 files belonging to 2 classes.

# %%
# Class 확인
class_names = train_ds.class_names
print(class_names)
# Out:
# ['COVID19', 'NORMAL']

# %%
#Train set에서 class 수 확인
num_images_train_normal = len(os.listdir(os.path.join(train_path,'NORMAL/')))
num_images_train_covid19 = len(os.listdir(os.path.join(train_path,'COVID19/')))

print(f"Normal data 수: {num_images_train_normal}")
print(f"COVID19 data 수: {num_images_train_covid19}")
# Out:
# Normal data 수: 1266
# COVID19 data 수: 460

# %%
# 이미지 load 가볍게 해줌

AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# 이미지 정규화
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# # CNN 모델 형성

# %%
#CNN 모델 형성
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(img_height, img_width, 3))) #128x128
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), padding='same', activation='relu')) #64x64
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128, (3,3), padding='same', activation='relu')) #32x32
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128, (3,3), padding='same', activation='relu')) #16x16
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       147584
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_3 (Dense)             (None, 128)               4194432
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,443,585
# Trainable params: 4,443,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
filename = 'checkpoint-epoch-{}-batch-{}-trial-001.h5'.format(epoch, batch_size)
checkpoint = ModelCheckpoint(filename,             # file명을 지정합니다
                             monitor='val_loss',   # val_loss 값이 개선되었을때 호출됩니다
                             verbose=1,            # 로그를 출력합니다
                             save_best_only=True,  # 가장 best 값만 저장합니다
                             mode='auto'           # auto는 알아서 best를 찾습니다. min/max
                            )

earlystopping = EarlyStopping(monitor='val_loss',  # 모니터 기준 설정 (val loss) 
                              patience=50,         # 50회 Epoch동안 개선되지 않는다면 종료
                             )

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 모델 훈련

# %%
model.fit(train_ds,
          batch_size=batch_size,
          validation_data=val_ds,
          epochs=epoch,
          callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.5538 - accuracy: 0.6385
# Epoch 00001: val_loss improved from inf to 0.36081, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 24s 503ms/step - loss: 0.5342 - accuracy: 0.6553 - val_loss: 0.3608 - val_accuracy: 0.9391
# Epoch 2/500
# 11/11 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9225
# Epoch 00002: val_loss improved from 0.36081 to 0.12327, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 1s 65ms/step - loss: 0.2138 - accuracy: 0.9225 - val_loss: 0.1233 - val_accuracy: 0.9391
# Epoch 3/500
# 11/11 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9522
# Epoch 00003: val_loss improved from 0.12327 to 0.09437, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 1s 65ms/step - loss: 0.1213 - accuracy: 0.9522 - val_loss: 0.0944 - val_accuracy: 0.9623
# Epoch 4/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9645
# Epoch 00004: val_loss improved from 0.09437 to 0.03855, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0958 - accuracy: 0.9645 - val_loss: 0.0385 - val_accuracy: 0.9884
# Epoch 5/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9732
# Epoch 00005: val_loss did not improve from 0.03855
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0801 - accuracy: 0.9732 - val_loss: 0.0614 - val_accuracy: 0.9768
# Epoch 6/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9747
# Epoch 00006: val_loss improved from 0.03855 to 0.03031, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0623 - accuracy: 0.9747 - val_loss: 0.0303 - val_accuracy: 0.9913
# Epoch 7/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9891
# Epoch 00007: val_loss did not improve from 0.03031
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0350 - accuracy: 0.9891 - val_loss: 0.0448 - val_accuracy: 0.9826
# Epoch 8/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9891
# Epoch 00008: val_loss improved from 0.03031 to 0.02332, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0326 - accuracy: 0.9891 - val_loss: 0.0233 - val_accuracy: 0.9913
# Epoch 9/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9928
# Epoch 00009: val_loss did not improve from 0.02332
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0175 - accuracy: 0.9928 - val_loss: 0.0339 - val_accuracy: 0.9913
# Epoch 10/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9928
# Epoch 00010: val_loss did not improve from 0.02332
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0201 - accuracy: 0.9928 - val_loss: 0.0244 - val_accuracy: 0.9913
# Epoch 11/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9812
# Epoch 00011: val_loss did not improve from 0.02332
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0562 - accuracy: 0.9812 - val_loss: 0.0363 - val_accuracy: 0.9884
# Epoch 12/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9855
# Epoch 00012: val_loss did not improve from 0.02332
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0304 - accuracy: 0.9855 - val_loss: 0.0286 - val_accuracy: 0.9855
# Epoch 13/500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0119 - accuracy: 0.9952
# Epoch 00013: val_loss did not improve from 0.02332
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0125 - accuracy: 0.9949 - val_loss: 0.0286 - val_accuracy: 0.9884
# Epoch 14/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9971
# Epoch 00014: val_loss did not improve from 0.02332
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.0295 - val_accuracy: 0.9884
# Epoch 15/500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0082 - accuracy: 0.9960
# Epoch 00015: val_loss improved from 0.02332 to 0.01991, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0077 - accuracy: 0.9964 - val_loss: 0.0199 - val_accuracy: 0.9942
# Epoch 16/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9993
# Epoch 00016: val_loss did not improve from 0.01991
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0293 - val_accuracy: 0.9884
# Epoch 17/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9978
# Epoch 00017: val_loss did not improve from 0.01991
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.0223 - val_accuracy: 0.9942
# Epoch 18/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9920
# Epoch 00018: val_loss did not improve from 0.01991
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0123 - accuracy: 0.9920 - val_loss: 0.0616 - val_accuracy: 0.9797
# Epoch 19/500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0069 - accuracy: 0.9976
# Epoch 00019: val_loss did not improve from 0.01991
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0534 - val_accuracy: 0.9855
# Epoch 20/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9978
# Epoch 00020: val_loss did not improve from 0.01991
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.0248 - val_accuracy: 0.9942
# Epoch 21/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00021: val_loss improved from 0.01991 to 0.01552, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 1s 65ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0155 - val_accuracy: 0.9913
# Epoch 22/500
# 11/11 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00022: val_loss improved from 0.01552 to 0.01425, saving model to checkpoint-epoch-500-batch-128-trial-001.h5
# 11/11 [==============================] - 1s 70ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9942
# Epoch 23/500
# 11/11 [==============================] - ETA: 0s - loss: 3.5333e-04 - accuracy: 1.0000
# Epoch 00023: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 50ms/step - loss: 3.5333e-04 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9942
# Epoch 24/500
# 11/11 [==============================] - ETA: 0s - loss: 1.8936e-04 - accuracy: 1.0000
# Epoch 00024: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 49ms/step - loss: 1.8936e-04 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9913
# Epoch 25/500
# 11/11 [==============================] - ETA: 0s - loss: 1.0659e-04 - accuracy: 1.0000
# Epoch 00025: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 50ms/step - loss:
- accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9913
# Epoch 60/500
# 11/11 [==============================] - ETA: 0s - loss: 3.8364e-06 - accuracy: 1.0000
# Epoch 00060: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 50ms/step - loss: 3.8364e-06 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9913
# Epoch 61/500
# 10/11 [==========================>...] - ETA: 0s - loss: 3.9806e-06 - accuracy: 1.0000
# Epoch 00061: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 51ms/step - loss: 3.6638e-06 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9913
# Epoch 62/500
# 11/11 [==============================] - ETA: 0s - loss: 3.5340e-06 - accuracy: 1.0000
# Epoch 00062: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 49ms/step - loss: 3.5340e-06 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9913
# Epoch 63/500
# 11/11 [==============================] - ETA: 0s - loss: 3.3781e-06 - accuracy: 1.0000
# Epoch 00063: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 50ms/step - loss: 3.3781e-06 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9913
# Epoch 64/500
# 10/11 [==========================>...] - ETA: 0s - loss: 2.9678e-06 - accuracy: 1.0000
# Epoch 00064: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 50ms/step - loss: 3.2792e-06 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 0.9913
# Epoch 65/500
# 10/11 [==========================>...] - ETA: 0s - loss: 3.3577e-06 - accuracy: 1.0000
# Epoch 00065: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 51ms/step - loss: 3.1479e-06 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9913
# Epoch 66/500
# 11/11 [==============================] - ETA: 0s - loss: 3.0356e-06 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 51ms/step - loss: 3.0356e-06 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9913
# Epoch 67/500
# 11/11 [==============================] - ETA: 0s - loss: 2.9107e-06 - accuracy: 1.0000
# Epoch 00067: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 51ms/step - loss: 2.9107e-06 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9913
# Epoch 68/500
# 11/11 [==============================] - ETA: 0s - loss: 2.8218e-06 - accuracy: 1.0000
# Epoch 00068: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 51ms/step - loss: 2.8218e-06 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9913
# Epoch 69/500
# 11/11 [==============================] - ETA: 0s - loss: 2.7258e-06 - accuracy: 1.0000
# Epoch 00069: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 50ms/step - loss: 2.7258e-06 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9913
# Epoch 70/500
# 11/11 [==============================] - ETA: 0s - loss: 2.6434e-06 - accuracy: 1.0000
# Epoch 00070: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 49ms/step - loss: 2.6434e-06 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9913
# Epoch 71/500
# 11/11 [==============================] - ETA: 0s - loss: 2.5471e-06 - accuracy: 1.0000
# Epoch 00071: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 51ms/step - loss: 2.5471e-06 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9913
# Epoch 72/500
# 11/11 [==============================] - ETA: 0s - loss: 2.4766e-06 - accuracy: 1.0000
# Epoch 00072: val_loss did not improve from 0.01425
# 11/11 [==============================] - 1s 50ms/step - loss: 2.4766e-06 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9913

# %%
model.evaluate(test_ds, verbose=2)
# Out:
# 4/4 - 6s - loss: 0.0951 - accuracy: 0.9792 - 6s/epoch - 1s/step
# [0.09512540698051453, 0.9792147874832153]

# %% [markdown]
# # 모델 저장

# %%
save_path = "/content/drive/MyDrive/CodeStates/Section4/project/"
file_name = 'before_GAN.pkl' 
save_path = os.path.join(save_path, file_name)

joblib.dump(model, save_path)
# Out:
# INFO:tensorflow:Assets written to: ram://a2bbd8e9-7b16-4341-9630-3d4d80e570a4/assets
# ['/content/drive/MyDrive/CodeStates/Section4/project/before_GAN.pkl']
